# %%
from dataloader import DataLoader

# %%
dataLoader = DataLoader(seed=42, truncate_length=4)
data = dataLoader.read_csv("../training_data_clean.csv")
# Out:
# Reading data from ../training_data_clean.csv...
# Cleaning data...

# %%
data.describe()
# Out:
#        student_id  How likely are you to use this model for academic tasks?  \
# count  825.000000                                         825.000000
# mean   138.000000                                           3.003636
# std     79.433293                                           1.263274
# min      1.000000                                           1.000000
# 25%     69.000000                                           2.000000
# 50%    138.000000                                           3.000000
# 75%    207.000000                                           4.000000
# max    275.000000                                           5.000000
#
#        Based on your experience, how often has this model given you a response that felt suboptimal?  \
# count                                         825.000000
# mean                                            2.877576
# std                                             0.900805
# min                                            -1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        How often do you expect this model to provide responses with references or supporting evidence?  \
# count                                         825.000000
# mean                                            2.526061
# std                                             1.459689
# min                                            -1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        How often do you verify this model's responses?       label
# count                                       825.000000  825.000000
# mean                                          3.151515    1.000000
# std                                           1.265707    0.816992
# min                                          -1.000000    0.000000
# 25%                                           2.000000    0.000000
# 50%                                           3.000000    1.000000
# 75%                                           4.000000    2.000000
# max                                           5.000000    2.000000

# %%
train_data, val_data, test_data = dataLoader.split_data(train_size=636, val_size=159, data=data)
train_data.head()
# Out:
#    student_id  \
# 0          94
# 1         129
# 2          68
# 3         163
# 4          31
#
#   In your own words, what kinds of tasks would you use this model for?  \
# 0  math and stat it also answ foll up ques and ca...
# 1  idea gene edit my writ summ long text and gene...
# 2  doin assi that allo gene ai usag expl lect sli...
# 3  rewo emai resp or answ for job appl unde spec ...
# 4  in one of my pers proj i actu used this mode t...
#
#    How likely are you to use this model for academic tasks?  \
# 0                                                  4
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#   Which types of tasks do you feel this model handles best? (Select all that apply.)  \
# 0                                             [0, 2]
# 1                                    [1, 3, 5, 6, 7]
# 2                           [0, 1, 2, 3, 4, 5, 6, 7]
# 3                                 [1, 3, 4, 5, 6, 7]
# 4                                          [0, 1, 3]
#
#    Based on your experience, how often has this model given you a response that felt suboptimal?  \
# 0                                                  4
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#   For which types of tasks do you feel this model tends to give suboptimal responses? (Select all that apply.)  \
# 0                                    [3, 4, 5, 6, 7]
# 1                                       [0, 1, 2, 4]
# 2                                          [0, 1, 7]
# 3                                          [0, 1, 2]
# 4                                             [5, 7]
#
#   Think of one task where this model gave you a suboptimal response. What did the response look like, and why did you find it suboptimal?  \
# 0  for math stat answ the form is very bad it s h...
# 1  this mode stru to gene math proo its resp will...
# 2  debu code usua the modi code does t work and i...
# 3  i was havi trou comi up with an answ to a prac...
# 4  i feel like this mode s writ styl is not the b...
#
#    How often do you expect this model to provide responses with references or supporting evidence?  \
# 0                                                  3
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    How often do you verify this model's responses?  \
# 0                                                3
# 1                                                3
# 2                                                4
# 3                                                2
# 4                                                2
#
#   When you verify a response from this model, how do you usually go about it?  \
# 0                         use goog sear or othe mode
# 1  goog the prom and see if arti or webs agre wit...
# 2  goog the answ conc to see if it alig with this...
# 3  if it is a resp that refe exte mate for exam h...
# 4  simi to anot mode i don t tend to veri the mod...
#
#    label
# 0      2
# 1      0
# 2      0
# 3      0
# 4      1

# %%
dataLoader.build_vocab(train_data)
print("Vocabulary size:", len(dataLoader._document_freq))
# Out:
# Vocabulary size: 3529

# %%
train_X, train_t = dataLoader.get_Xt(data)
train_X.shape, train_t.shape
# Out:
# ((825, 10623), (825,))
