# %% [markdown]
# # Random Forest (BoW)

# %% [markdown]
# ## Config Setup

# %% [markdown]
# ### 1. Import Libraries + Setup

# %%
import sys
sys.path.append('..')

import numpy as np
import json

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score

from src.dataloader import DataLoader
from models.decision_trees.random_forest import RandomForestModel
from helpers.save_model_params import extract_rf_to_dict

# Configs
json_path = '../models/decision_trees/fitted_bow_rf.json'
train_data_path = '../src/data/train_data.csv'
val_data_path = '../src/data/validation_data.csv'
test_data_path = '../src/data/test_data.csv'
random_seed = 42

hyperparams = {
    "random_state": random_seed,
    "n_estimators": [100, 200, 500, 1000],
    "max_features": ['sqrt', 'log2'],
    "max_depth": [5, 10, 15, 20, 25, 30],
    "min_samples_split": [2, 4, 8, 16],
    "min_samples_leaf": [1, 5, 10],
    "criterion": ["gini", "entropy"],
}

# %% [markdown]
# ### 2. Generate Training and Validation Data (BoW)

# %%
dataloader = DataLoader(random_seed)
X_train, y_train = dataloader.generate_Xt(train_data_path)
X_val, y_val = dataloader.generate_Xt(val_data_path)

# %% [markdown]
# ### 3. Function to generate Fitted Random Forests w/ hyperparameter permutations

# %%
def search_hyperparameters(X_train, y_train, X_val, y_val):
    best_acc = 0.0
    best_params = {}

    for n_estimators in hyperparams["n_estimators"]:
        for max_features in hyperparams["max_features"]:
            for max_depth in hyperparams["max_depth"]:
                for min_samples_split in hyperparams["min_samples_split"]:
                    for min_samples_leaf in hyperparams["min_samples_leaf"]:
                        for criterion in hyperparams["criterion"]:
                            model = RandomForestClassifier(
                                n_estimators=n_estimators,
                                max_features=max_features,
                                max_depth=max_depth,
                                min_samples_split=min_samples_split,
                                min_samples_leaf=min_samples_leaf,
                                criterion=criterion,
                                random_state=random_seed
                            )
                            model.fit(X_train, y_train)
                            y_val_pred = model.predict(X_val)
                            val_accuracy = accuracy_score(y_val, y_val_pred)

                            if val_accuracy > best_acc:
                                best_acc = val_accuracy
                                best_params = {
                                    "n_estimators": n_estimators,
                                    "max_features": max_features,
                                    "max_depth": max_depth,
                                    "min_samples_split": min_samples_split,
                                    "min_samples_leaf": min_samples_leaf,
                                    "criterion": criterion
                                }

                            print(f"Params: max_depth={max_depth}, min_samples_split={min_samples_split}, "
                                    f"criterion={criterion}, min_samples_leaf={min_samples_leaf}, \n\t => Validation Accuracy: {val_accuracy:.4f}")

    return best_params

# %% [markdown]
# ## Find Best Random Forest

# %% [markdown]
# ### 1. Find best hyperparameter permutations

# %%
best_hyperparams = search_hyperparameters(X_train, y_train, X_val, y_val)
print("Best Hyperparameters:")
for param, value in best_hyperparams.items():
    print(f"{param}: {value}")
# Out:
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7667
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=5, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=10, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7333
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7333
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7333
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7667
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=15, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8667
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.7867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7333
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7667
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=20, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7600
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7667
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.7067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7467
# ...
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9133
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.8933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=25, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9267
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=2, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9200
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=4, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9067
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7733
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=8, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=gini, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=entropy, min_samples_leaf=1,
# 	 => Validation Accuracy: 0.9000
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=gini, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7533
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=entropy, min_samples_leaf=5,
# 	 => Validation Accuracy: 0.7400
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=gini, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6867
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Params: max_depth=30, min_samples_split=16, criterion=entropy, min_samples_leaf=10,
# 	 => Validation Accuracy: 0.6933
# Best Hyperparameters:
# n_estimators: 500
# max_features: log2
# max_depth: 25
# min_samples_split: 2
# min_samples_leaf: 1
# criterion: gini

# %% [markdown]
# ## Generate Best Random Forest w/ Best Hyperparameters and Save Splits to JSON

# %% [markdown]
# ### 1. Generate Random Forest w/ Best Hyperparameters

# %%
# Best Hyperparams: {'n_estimators': 500, 'max_features': 'log2', 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}

sklearn_rf = RandomForestClassifier(
    n_estimators=best_hyperparams["n_estimators"],
    max_features=best_hyperparams["max_features"],
    max_depth=best_hyperparams["max_depth"],
    criterion=best_hyperparams["criterion"],
    min_samples_split=best_hyperparams["min_samples_split"],
    min_samples_leaf=best_hyperparams["min_samples_leaf"],
    random_state=random_seed
)

sklearn_rf.fit(X_train, y_train)

y_pred_val = sklearn_rf.predict(X_val)
y_pred_train = sklearn_rf.predict(X_train)
val_accuracy = accuracy_score(y_val, y_pred_val)
train_accuracy = accuracy_score(y_train, y_pred_train)

print(f"Best Hyperparams: {best_hyperparams}")
print(f"Validation Accuracy: {val_accuracy:.4f}\n Training Accuracy: {train_accuracy:.4f}")
# Out:
# /home/tshafiq/.local/lib/python3.10/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Best Hyperparams: {'n_estimators': 500, 'max_features': 'log2', 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}
# Validation Accuracy: 0.9467
#  Training Accuracy: 0.9830

# %% [markdown]
# ### 2. Extract splits to JSON

# %%
rf_dict = extract_rf_to_dict(sklearn_rf)

with open(json_path, 'w') as f:
    json.dump(rf_dict, f, indent=2)
    
print(f"Random forest saved to: {json_path}")
# Out:
# Random forest saved to: ../models/decision_trees/fitted_bow_rf.json

# %% [markdown]
# ## Verify Correct Random Forest Saved Correctly

# %% [markdown]
# ### 1. Build saved Random Forest from JSON

# %%
custom_rf = RandomForestModel(json_path)
# Out:
# Random Forest with 500 trees loaded from: ../models/decision_trees/fitted_bow_rf.json

# %% [markdown]
# ### 2. Generate Predictions from Extracted Splits and Verify Predictions Made

# %%
sklearn_train_preds = sklearn_rf.predict(X_train)
custom_train_preds = custom_rf.predict(X_train.to_numpy())

sklearn_val_predictions = sklearn_rf.predict(X_val)
custom_val_predictions = custom_rf.predict(X_val.to_numpy())

train_matches = np.sum(sklearn_train_preds == custom_train_preds)
train_total = len(X_train)

val_matches = np.sum(sklearn_val_predictions == custom_val_predictions)
val_total = len(X_val)

print(f"Training Predictions match: {train_matches}/{train_total}")
print(f"\nsklearn training accuracy: {accuracy_score(y_train, sklearn_train_preds):.4f}")
print(f"Custom training accuracy: {accuracy_score(y_train, custom_train_preds):.4f}\n")

print(f"Validation Predictions match: {val_matches}/{val_total}")
print(f"\nsklearn validation accuracy: {accuracy_score(y_val, sklearn_val_predictions):.4f}")
print(f"Custom validation accuracy: {accuracy_score(y_val, custom_val_predictions):.4f}")
# Out:
# Training Predictions match: 648/648
#
# sklearn training accuracy: 0.9830
# Custom training accuracy: 0.9830
#
# Validation Predictions match: 150/150
#
# sklearn validation accuracy: 0.9467
# Custom validation accuracy: 0.9467
