# %%
import numpy as np
import sys
sys.path.append('..')

clean_training_data_path = '../../training_data_clean.csv'

from dataloader_std import DataLoader

dl = DataLoader()
dl.read_csv(clean_training_data_path)
dl.generate_Xt_files()
